# %%
from google.colab import drive
drive.mount('/content/drive') 
# %cd /content/drive/MyDrive/ECE_740/depth_image_enhancement_for_UAV_exploration
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/ECE_740/depth_image_enhancement_for_UAV_exploration

# %%
# reload google drive files without restarting the session
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from networks.train import train
train()
# Out:
# Autoencoder(
#   (encoder): Encoder(
#     (encoder): Sequential(
#       (0): Conv2d(1, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Dropout(p=0.5, inplace=False)
#       (4): Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (5): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): ReLU(inplace=True)
#       (7): Dropout(p=0.5, inplace=False)
#       (8): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (9): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (10): ReLU(inplace=True)
#     )
#   )
#   (decoder): Decoder(
#     (decoder): Sequential(
#       (0): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
# ...

# %%
# reduce number of channels to 3!!
from networks.train_left import train
train()
# Out:
# Autoencoder(
#   (encoder): Encoder(
#     (encoder): Sequential(
#       (0): Conv2d(3, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Dropout(p=0.5, inplace=False)
#       (4): Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (5): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): ReLU(inplace=True)
#       (7): Dropout(p=0.5, inplace=False)
#       (8): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (9): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (10): ReLU(inplace=True)
#     )
#   )
#   (decoder): Decoder(
#     (decoder): Sequential(
#       (0): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
# ...

# %%
from networks.train_stereo import train
train()
# Out:
# StereoAutoencoder(
#   (encoder): Encoder(
#     (encoder): Sequential(
#       (0): Conv2d(4, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Dropout(p=0.5, inplace=False)
#       (4): Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (5): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): ReLU(inplace=True)
#       (7): Dropout(p=0.5, inplace=False)
#       (8): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (9): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (10): ReLU(inplace=True)
#     )
#   )
#   (decoder): Decoder(
#     (decoder): Sequential(
#       (0): ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ...

# %%
import os
import skimage.io as io
import numpy as np
import matplotlib.pyplot as plt

input_path = os.path.join('../python_images_new','high_light/high_left')
input_name = os.path.join(input_path, 'image_'+str(1)+'.png')
input = io.imread(input_name)
input = np.divide(input, 255)

# %%
input.shape
# Out:
# (720, 1280, 4)

# %%
plt.imshow(input[:,:,:3])

# %%
input_path = os.path.join('../python_images_new','low_light/low_depth')
input_name = os.path.join(input_path, 'image_'+str(1)+'.png')
input = io.imread(input_name)
input = np.divide(input, 255)

# %%
input.shape
# Out:
# (720, 1280)

# %%
plt.imshow(input)

# %%
input
# Out:
# array([[[0.03529412, 0.03137255, 0.02352941, 1.        ],
#         [0.04313725, 0.03921569, 0.03137255, 1.        ],
#         [0.05098039, 0.04705882, 0.03921569, 1.        ],
#         ...,
#         [0.02352941, 0.01960784, 0.00784314, 1.        ],
#         [0.03137255, 0.02745098, 0.01176471, 1.        ],
#         [0.03137255, 0.02745098, 0.01960784, 1.        ]],
#
#        [[0.03921569, 0.03529412, 0.02745098, 1.        ],
#         [0.03529412, 0.03137255, 0.02352941, 1.        ],
#         [0.03529412, 0.03137255, 0.02352941, 1.        ],
#         ...,
#         [0.02352941, 0.01960784, 0.00392157, 1.        ],
#         [0.02352941, 0.01960784, 0.00392157, 1.        ],
#         [0.02352941, 0.01960784, 0.01176471, 1.        ]],
#
#        [[0.03921569, 0.03529412, 0.02745098, 1.        ],
#         [0.03921569, 0.03529412, 0.02745098, 1.        ],
#         [0.03921569, 0.03529412, 0.02745098, 1.        ],
#         ...,
# ...

# %%
input
# Out:
# array([[0.        , 0.        , 0.        , ..., 0.59607843, 0.59607843,
#         0.59607843],
#        [0.        , 0.        , 0.        , ..., 0.59215686, 0.59215686,
#         0.59607843],
#        [0.        , 0.        , 0.        , ..., 0.58039216, 0.59215686,
#         0.59215686],
#        ...,
#        [0.        , 0.        , 0.        , ..., 0.72156863, 0.65098039,
#         0.64313725],
#        [0.        , 0.        , 0.        , ..., 0.71764706, 0.64313725,
#         0.64313725],
#        [0.        , 0.        , 0.        , ..., 0.65490196, 0.64313725,
#         0.64313725]])

# %%
input.shape
# Out:
# (720, 1280)
