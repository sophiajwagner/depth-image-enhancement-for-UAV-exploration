# %%
from google.colab import drive
drive.mount('/content/drive') 
# %cd /content/drive/MyDrive/ECE_740/depth_image_enhancement_for_UAV_exploration
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/ECE_740/depth_image_enhancement_for_UAV_exploration

# %%
# reload google drive files without restarting the session
# %load_ext autoreload
# %autoreload 2

# %%
from networks.train import train

# %%
train()
# Out:
# Autoencoder(
#   (encoder): Encoder(
#     (encoder): Sequential(
#       (0): Conv2d(1, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Dropout(p=0.5, inplace=False)
#       (4): Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (5): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): ReLU(inplace=True)
#       (7): Dropout(p=0.5, inplace=False)
#       (8): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (9): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (10): ReLU(inplace=True)
#     )
#   )
#   (decoder): Decoder(
#     (decoder): Sequential(
#       (0): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): ConvTranspose2d(16, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (4): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#       (6): ConvTranspose2d(8, 1, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (7): Sigmoid()
#     )
#   )
# )
# 	 partial train loss (single batch): 0.728537
# 	 partial train loss (single batch): 0.724568
# 	 partial train loss (single batch): 0.715750
# 	 partial train loss (single batch): 0.707921
#
#  EPOCH 1/40 	 train loss 0.7191939353942871 	 val loss 0.6951412558555603
# 	 partial train loss (single batch): 0.697138
# 	 partial train loss (single batch): 0.699229
# 	 partial train loss (single batch): 0.689040
# 	 partial train loss (single batch): 0.689965
#
#  EPOCH 2/40 	 train loss 0.6938431262969971 	 val loss 0.6922958493232727
# 	 partial train loss (single batch): 0.683625
# 	 partial train loss (single batch): 0.677548
# 	 partial train loss (single batch): 0.673756
# 	 partial train loss (single batch): 0.667158
#
#  EPOCH 3/40 	 train loss 0.6755215525627136 	 val loss 0.6876900792121887
# 	 partial train loss (single batch): 0.671769
# 	 partial train loss (single batch): 0.666051
# 	 partial train loss (single batch): 0.662426
# 	 partial train loss (single batch): 0.656868
#
#  EPOCH 4/40 	 train loss 0.6642787456512451 	 val loss 0.6796272397041321
# 	 partial train loss (single batch): 0.661117
# 	 partial train loss (single batch): 0.649417
# 	 partial train loss (single batch): 0.660760
# 	 partial train loss (single batch): 0.652101
# torch.Size([20, 1, 720, 1280])
# torch.Size([20, 1, 720, 1280])
#  EPOCH 5/40 	 train loss 0.6558488607406616 	 val loss 0.6687747240066528
# 	 partial train loss (single batch): 0.647293
# 	 partial train loss (single batch): 0.648440
# 	 partial train loss (single batch): 0.651957
# 	 partial train loss (single batch): 0.646813
#
#  EPOCH 6/40 	 train loss 0.6486257910728455 	 val loss 0.6573004722595215
# 	 partial train loss (single batch): 0.652570
# 	 partial train loss (single batch): 0.639915
# 	 partial train loss (single batch): 0.636990
# 	 partial train loss (single batch): 0.635422
#
#  EPOCH 7/40 	 train loss 0.6412241458892822 	 val loss 0.6467315554618835
# 	 partial train loss (single batch): 0.633053
# 	 partial train loss (single batch): 0.638454
# 	 partial train loss (single batch): 0.648491
# 	 partial train loss (single batch): 0.620924
#
#  EPOCH 8/40 	 train loss 0.635230302810669 	 val loss 0.637424111366272
# 	 partial train loss (single batch): 0.632357
# 	 partial train loss (single batch): 0.635139
# 	 partial train loss (single batch): 0.625610
# 	 partial train loss (single batch): 0.626483
#
#  EPOCH 9/40 	 train loss 0.6298973560333252 	 val loss 0.6286775469779968
# 	 partial train loss (single batch): 0.628240
# 	 partial train loss (single batch): 0.617265
# 	 partial train loss (single batch): 0.631666
# 	 partial train loss (single batch): 0.621938
# torch.Size([20, 1, 720, 1280])
# torch.Size([20, 1, 720, 1280])
#  EPOCH 10/40 	 train loss 0.6247773170471191 	 val loss 0.6198844313621521
# 	 partial train loss (single batch): 0.623531
# 	 partial train loss (single batch): 0.607718
# 	 partial train loss (single batch): 0.627708
# 	 partial train loss (single batch): 0.620990
#
#  EPOCH 11/40 	 train loss 0.6199867725372314 	 val loss 0.6124195456504822
# 	 partial train loss (single batch): 0.606108
# 	 partial train loss (single batch): 0.609809
# 	 partial train loss (single batch): 0.640506
# 	 partial train loss (single batch): 0.611560
#
#  EPOCH 12/40 	 train loss 0.6169960498809814 	 val loss 0.6071877479553223
# 	 partial train loss (single batch): 0.616405
# 	 partial train loss (single batch): 0.602856
# 	 partial train loss (single batch): 0.619163
# 	 partial train loss (single batch): 0.616061
#
#  EPOCH 13/40 	 train loss 0.6136212944984436 	 val loss 0.6034541130065918
# 	 partial train loss (single batch): 0.613175
# 	 partial train loss (single batch): 0.603647
# 	 partial train loss (single batch): 0.613444
# 	 partial train loss (single batch): 0.609463
#
#  EPOCH 14/40 	 train loss 0.6099321842193604 	 val loss 0.6007334589958191
# 	 partial train loss (single batch): 0.603861
# 	 partial train loss (single batch): 0.618382
# 	 partial train loss (single batch): 0.594343
# 	 partial train loss (single batch): 0.615429
# torch.Size([20, 1, 720, 1280])
# torch.Size([20, 1, 720, 1280])
#  EPOCH 15/40 	 train loss 0.6080037355422974 	 val loss 0.5986155271530151
# 	 partial train loss (single batch): 0.614736
# 	 partial train loss (single batch): 0.604107
# 	 partial train loss (single batch): 0.602904
# 	 partial train loss (single batch): 0.598081
#
#  EPOCH 16/40 	 train loss 0.6049569845199585 	 val loss 0.5974258780479431
# 	 partial train loss (single batch): 0.606962
# 	 partial train loss (single batch): 0.614578
# 	 partial train loss (single batch): 0.597700
# 	 partial train loss (single batch): 0.595283
#
#  EPOCH 17/40 	 train loss 0.6036309003829956 	 val loss 0.5960089564323425
# 	 partial train loss (single batch): 0.598067
# 	 partial train loss (single batch): 0.598544
# 	 partial train loss (single batch): 0.611406
# 	 partial train loss (single batch): 0.598364
#
#  EPOCH 18/40 	 train loss 0.6015952825546265 	 val loss 0.594779372215271
# 	 partial train loss (single batch): 0.599963
# 	 partial train loss (single batch): 0.591763
# 	 partial train loss (single batch): 0.610430
# 	 partial train loss (single batch): 0.598147
#
#  EPOCH 19/40 	 train loss 0.6000757813453674 	 val loss 0.5954031944274902
# 	 partial train loss (single batch): 0.589226
# 	 partial train loss (single batch): 0.595304
# 	 partial train loss (single batch): 0.604193
# 	 partial train loss (single batch): 0.605128
# torch.Size([20, 1, 720, 1280])
# torch.Size([20, 1, 720, 1280])
#  EPOCH 20/40 	 train loss 0.5984628796577454 	 val loss 0.5967350006103516
# 	 partial train loss (single batch): 0.598278
# 	 partial train loss (single batch): 0.604238
# 	 partial train loss (single batch): 0.600219
# 	 partial train loss (single batch): 0.584651
#
#  EPOCH 21/40 	 train loss 0.5968464016914368 	 val loss 0.5964523553848267
# 	 partial train loss (single batch): 0.598328
# 	 partial train loss (single batch): 0.597149
# 	 partial train loss (single batch): 0.592919
# 	 partial train loss (single batch): 0.596093
#
#  EPOCH 22/40 	 train loss 0.5961223244667053 	 val loss 0.5945810675621033
# 	 partial train loss (single batch): 0.606165
# 	 partial train loss (single batch): 0.591142
# 	 partial train loss (single batch): 0.585629
# 	 partial train loss (single batch): 0.596515
#
#  EPOCH 23/40 	 train loss 0.5948628783226013 	 val loss 0.5900279879570007
# 	 partial train loss (single batch): 0.589553
# 	 partial train loss (single batch): 0.586573
# 	 partial train loss (single batch): 0.606337
# 	 partial train loss (single batch): 0.595012
#
#  EPOCH 24/40 	 train loss 0.5943686366081238 	 val loss 0.5869460701942444
# 	 partial train loss (single batch): 0.596222
# 	 partial train loss (single batch): 0.572446
# 	 partial train loss (single batch): 0.588681
# 	 partial train loss (single batch): 0.615036
# torch.Size([20, 1, 720, 1280])
# torch.Size([20, 1, 720, 1280])
#  EPOCH 25/40 	 train loss 0.5930963754653931 	 val loss 0.5850266814231873
# 	 partial train loss (single batch): 0.574783
# 	 partial train loss (single batch): 0.597036
# 	 partial train loss (single batch): 0.586977
# 	 partial train loss (single batch): 0.607460
#
#  EPOCH 26/40 	 train loss 0.5915639996528625 	 val loss 0.5843706130981445
# 	 partial train loss (single batch): 0.583636
# 	 partial train loss (single batch): 0.604453
# 	 partial train loss (single batch): 0.586729
# 	 partial train loss (single batch): 0.591535
#
#  EPOCH 27/40 	 train loss 0.591588020324707 	 val loss 0.5827060341835022
# 	 partial train loss (single batch): 0.594759
# 	 partial train loss (single batch): 0.589857
# 	 partial train loss (single batch): 0.600587
# 	 partial train loss (single batch): 0.575477
#
#  EPOCH 28/40 	 train loss 0.59017014503479 	 val loss 0.5809767842292786
# 	 partial train loss (single batch): 0.599420
# 	 partial train loss (single batch): 0.584594
# 	 partial train loss (single batch): 0.578002
# 	 partial train loss (single batch): 0.594459
#
#  EPOCH 29/40 	 train loss 0.5891189575195312 	 val loss 0.579620361328125
# 	 partial train loss (single batch): 0.608960
# 	 partial train loss (single batch): 0.579815
# 	 partial train loss (single batch): 0.578610
# 	 partial train loss (single batch): 0.589111
# torch.Size([20, 1, 720, 1280])
# torch.Size([20, 1, 720, 1280])
#  EPOCH 30/40 	 train loss 0.5891238451004028 	 val loss 0.5772846937179565
# 	 partial train loss (single batch): 0.595685
# 	 partial train loss (single batch): 0.587727
# 	 partial train loss (single batch): 0.567136
# 	 partial train loss (single batch): 0.603545
#
#  EPOCH 31/40 	 train loss 0.588523268699646 	 val loss 0.5755584836006165
# 	 partial train loss (single batch): 0.579438
# 	 partial train loss (single batch): 0.585443
# 	 partial train loss (single batch): 0.585749
# 	 partial train loss (single batch): 0.602365
#
#  EPOCH 32/40 	 train loss 0.5882490873336792 	 val loss 0.574611485004425
# 	 partial train loss (single batch): 0.579443
# 	 partial train loss (single batch): 0.611981
# 	 partial train loss (single batch): 0.560300
# 	 partial train loss (single batch): 0.594893
#
#  EPOCH 33/40 	 train loss 0.5866541862487793 	 val loss 0.574094295501709
# 	 partial train loss (single batch): 0.585863
# 	 partial train loss (single batch): 0.601998
# 	 partial train loss (single batch): 0.566081
# 	 partial train loss (single batch): 0.592540
#
#  EPOCH 34/40 	 train loss 0.5866206884384155 	 val loss 0.574170708656311
# 	 partial train loss (single batch): 0.586714
# 	 partial train loss (single batch): 0.594510
# 	 partial train loss (single batch): 0.566369
# 	 partial train loss (single batch): 0.595034
# torch.Size([20, 1, 720, 1280])
# torch.Size([20, 1, 720, 1280])
#  EPOCH 35/40 	 train loss 0.5856566429138184 	 val loss 0.5746245980262756
# 	 partial train loss (single batch): 0.591644
# 	 partial train loss (single batch): 0.576210
# 	 partial train loss (single batch): 0.593907
# 	 partial train loss (single batch): 0.577650
#
#  EPOCH 36/40 	 train loss 0.5848524570465088 	 val loss 0.5730571150779724
# 	 partial train loss (single batch): 0.593738
# 	 partial train loss (single batch): 0.578995
# 	 partial train loss (single batch): 0.575750
# 	 partial train loss (single batch): 0.589964
#
#  EPOCH 37/40 	 train loss 0.5846120119094849 	 val loss 0.5732499957084656
# 	 partial train loss (single batch): 0.592192
# 	 partial train loss (single batch): 0.601322
# 	 partial train loss (single batch): 0.570909
# 	 partial train loss (single batch): 0.570554
#
#  EPOCH 38/40 	 train loss 0.5837443470954895 	 val loss 0.5720593929290771
# 	 partial train loss (single batch): 0.574288
# 	 partial train loss (single batch): 0.577604
# 	 partial train loss (single batch): 0.603595
# 	 partial train loss (single batch): 0.581539
#
#  EPOCH 39/40 	 train loss 0.5842564702033997 	 val loss 0.5698806643486023
# 	 partial train loss (single batch): 0.581061
# 	 partial train loss (single batch): 0.576999
# 	 partial train loss (single batch): 0.579221
# 	 partial train loss (single batch): 0.597539
# torch.Size([20, 1, 720, 1280])
# torch.Size([20, 1, 720, 1280])
#  EPOCH 40/40 	 train loss 0.5837050676345825 	 val loss 0.5691094398498535

# %%
from networks.train_stereo import train
train()
# Out:
# StereoAutoencoder(
#   (encoder): Encoder(
#     (encoder): Sequential(
#       (0): Conv2d(4, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Dropout(p=0.5, inplace=False)
#       (4): Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (5): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): ReLU(inplace=True)
#       (7): Dropout(p=0.5, inplace=False)
#       (8): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (9): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (10): ReLU(inplace=True)
#     )
#   )
#   (decoder): Decoder(
#     (decoder): Sequential(
#       (0): ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#       (6): ConvTranspose2d(16, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (7): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU(inplace=True)
#       (9): ConvTranspose2d(8, 1, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (10): Sigmoid()
#     )
#   )
# )
# 	 partial train loss (single batch): 0.742860
# 	 partial train loss (single batch): 0.734457
# 	 partial train loss (single batch): 0.720130
# 	 partial train loss (single batch): 0.718314
# torch.Size([20, 1, 720, 1280])
# torch.Size([20, 1, 720, 1280])
#  EPOCH 1/40 	 train loss 0.7289402484893799 	 val loss 0.6955277919769287
# 	 partial train loss (single batch): 0.713324
# 	 partial train loss (single batch): 0.709139
# 	 partial train loss (single batch): 0.706725
# 	 partial train loss (single batch): 0.704968
# torch.Size([20, 1, 720, 1280])
# torch.Size([20, 1, 720, 1280])
#  EPOCH 2/40 	 train loss 0.7085389494895935 	 val loss 0.6946223378181458
# 	 partial train loss (single batch): 0.703220
# 	 partial train loss (single batch): 0.702232
# 	 partial train loss (single batch): 0.701103
# 	 partial train loss (single batch): 0.699345
# torch.Size([20, 1, 720, 1280])
# torch.Size([20, 1, 720, 1280])
#  EPOCH 3/40 	 train loss 0.7014752626419067 	 val loss 0.6937659978866577
# 	 partial train loss (single batch): 0.699790
# 	 partial train loss (single batch): 0.697530
# 	 partial train loss (single batch): 0.697402
# 	 partial train loss (single batch): 0.696008
# torch.Size([20, 1, 720, 1280])
# torch.Size([20, 1, 720, 1280])
#  EPOCH 4/40 	 train loss 0.6976826786994934 	 val loss 0.6930820941925049
# 	 partial train loss (single batch): 0.695872

# %%
import os
import skimage.io as io
import numpy as np
import matplotlib.pyplot as plt

input_path = os.path.join('../python_images_new','low_light/low_left')
input_name = os.path.join(input_path, 'image_'+str(1)+'.png')
input = io.imread(input_name)
input = np.divide(input, 255)

# %%
input.shape
# Out:
# (720, 1280, 4)

# %%
input_path = os.path.join('../python_images_new','low_light/low_depth')
input_name = os.path.join(input_path, 'image_'+str(1)+'.png')
input = io.imread(input_name)
input = np.divide(input, 255)

# %%
input.shape
# Out:
# (720, 1280)

# %%
plt.imshow(input)
